# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None

class LinkedList:
    def __init__(self):
        self.head = None

    def push(self,new_data):
        new_node = Node(new_data)
        new_node.next = self.head
        self.head = new_node
    
    def delete(self,node):
        if node is None or node.next is None:
            print("Cannot delete this node")
            return
        node.data = node.next.data
        node.next = node.next.next

list = LinkedList()
a = list(map(int, input("Enter the numbers:").split()))
node = int(input())
for i in a:
    list.push(i)
list.delete(list.node)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 20
#      16         node.data = node.next.data
#      17         node.next = node.next.next
#      18
#      19 list = LinkedList()
# ---> 20 a = list(map(int, input("Enter the numbers:").split()))
#      21 node = int(input())
#      22 for i in a:
#      23     list.push(i)
#
# TypeError: 'LinkedList' object is not callable
